# %% [markdown]
# # Reinforcement Learning Algorithms Demo
#
# This notebook demonstrates Dynamic Programming, REINFORCE, PPO, and TRPO using the `rl_algorithms.py` module.

# %%
from rl_algorithms import run_all_algorithms

results = run_all_algorithms()
results

# %%
import json
print(json.dumps(results, indent=2))
